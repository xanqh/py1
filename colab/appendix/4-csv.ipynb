# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2025-11-28 23:13:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2025-11-28 23:13:33 (17.5 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2025-11-28 23:13:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.003s
#
# 2025-11-28 23:13:33 (10.2 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2025-11-28 23:13:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2025-11-28 23:13:33 (1.72 MB/s) - ‘./small.csv’ saved [45/45]
#
# --2025-11-28 23:13:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2025-11-28 23:13:34 (11.8 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2025-11-28 23:13:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2025-11-28 23:13:34 (322 KB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2025-11-28 23:13:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.003s
#
# 2025-11-28 23:13:34 (11.0 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2025-11-28 23:13:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2025-11-28 23:13:34 (2.17 MB/s) - ‘./sample.py’ saved [46/46]
#
# --2025-11-28 23:13:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0.001s
#
# 2025-11-28 23:13:35 (6.40 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2025-11-28 23:13:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0.005s
#
# 2025-11-28 23:13:35 (7.89 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2025-11-28 23:13:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.01s
#
# 2025-11-28 23:13:35 (6.01 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2025-11-28 23:13:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0.001s
#
# 2025-11-28 23:13:35 (19.9 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2025-11-28 23:13:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0.004s
#
# 2025-11-28 23:13:35 (2.97 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2025-11-28 23:13:36--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0.001s
#
# 2025-11-28 23:13:36 (24.0 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2025-11-28 23:13:36--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.004s
#
# 2025-11-28 23:13:36 (9.33 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2025-11-28 23:13:36--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2025-11-28 23:13:36 (23.5 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2025-11-28 23:13:36--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.002s
#
# 2025-11-28 23:13:36 (9.99 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2025-11-28 23:13:36--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.01s
#
# 2025-11-28 23:13:37 (4.86 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2025-11-28 23:13:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0s
#
# 2025-11-28 23:13:37 (101 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2025-11-28 23:13:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.03s
#
# 2025-11-28 23:13:37 (9.00 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2025-11-28 23:13:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.01s
#
# 2025-11-28 23:13:37 (4.96 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2025-11-28 23:13:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.001s
#
# 2025-11-28 23:13:37 (11.6 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2025-11-28 23:13:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0s
#
# 2025-11-28 23:13:38 (54.9 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2025-11-28 23:13:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.01s
#
# 2025-11-28 23:13:38 (5.05 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2025-11-28 23:13:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.003s
#
# 2025-11-28 23:13:38 (10.4 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2025-11-28 23:13:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.01s
#
# 2025-11-28 23:13:38 (4.56 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲CSVファイルの入出力
# CSVファイルの入出力について説明します。
#
# 参考
#
# - https://docs.python.org/ja/3/library/csv.html
#
# ## CSV形式とは
#
# **CSV**形式とは "comma-separated values" の略で、
# 複数の値をコンマで区切って記録するファイル形式です。
#
# みなさんExcelを使ったことがあると思いますが、
# Excelでは1つのセルに1つの値（数値や文字など）が入っていて、
# その他のセルの値とは独立に扱えますよね。
#
# それと同じように、CSV形式では、`,`（コンマ）で区切られた要素はそれぞれ独立の値として扱われます。
#
# たとえばサークルのメンバーデータを作ることを考えましょう。
# メンバーは「鈴木一郎」と「山田花子」の2名で、
# それぞれ『氏名』『ニックネーム』『出身地』を記録しておきたいと思います。
#
# 表で表すとこんなデータです。
#
# |ID| 氏名 | ニックネーム | 出身地 |
# |---:|:--------|:---------------|:-------|
# |user1| 鈴木一郎 | イチロー | 広島 |
# |user2| 山田花子 | はなこ | 名古屋 |
#
# これをCSV形式で表すと次のようになります。

# %% [raw]
# 'user1','鈴木一郎','イチロー','広島'
# 'user2','山田花子','はなこ','名古屋'

# %% [markdown]
# ## CSVファイルの読み込み
# CSVファイルを読み書きするには、
# ファイルをオープンして、そのファイルオブジェクトから、
# CSVリーダを作ります。
#
# **CSVリーダ**とは、CSVファイルからデータを読み込むためのオブジェクトで、
# このオブジェクトのメソッドを呼び出すことにより、CSVファイルからデータを読み込むことができます。
#
# CSVリーダを作るには、
# **`csv`** というモジュールの **`csv.reader`** という関数にファイルオブジェクトを渡します。
#
# たとえば、次のような表で表されるCSVファイル `small.csv` を読み込んでみましょう。
#
#  0列目 | 1列目 | 2列目 | 3列目 | 4列目
# ---|---|---|---|---
#  11 | 12 | 13 | 14 | 15
#  21 | 22 | 23 | 24 | 25
#  31 | 32 | 33 | 34 | 35

# %%
import csv
f = open('small.csv', 'r')
dataReader = csv.reader(f)

# %% [markdown]
# このオブジェクトもイテレータで、`next` という関数を呼び出すことができます。

# %%
next(dataReader)
# Out:
# ['11', '12', '13', '14', '15']

# %% [markdown]
# このようにして CSVファイルを読むと、
# CSVファイルの各行のデータが文字列のリストとなって返されます。

# %%
next(dataReader)
# Out:
# ['21', '22', '23', '24', '25']

# %%
row = next(dataReader)

# %%
row
# Out:
# ['31', '32', '33', '34', '35']

# %%
row[2]
# Out:
# '33'

# %% [markdown]
# 数値が `''` で囲われている場合、数値ではなく文字列として扱われているので、そのまま計算に使用することができません。
#
# 文字列が整数を表す場合、**`int`** 関数によって文字列を整数に変換することができます。
# 文字列が小数を含む場合は **`float`** 関数で浮動小数点数型に変換、文字列が複素数を表す場合は **`complex`** 関数で複素数に変換します。

# %%
int(row[2])
# Out:
# 33

# %% [markdown]
# ファイルの終わりまで達した後に `next` 関数を実行すると、下のようにエラーが返ってきます。

# %%
next(dataReader)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-2968410705.py in <cell line: 0>()
# ----> 1 next(dataReader)
#
# StopIteration:

# %% [markdown]
# ファイルを使い終わったらクローズすることを忘れないようにしましょう。

# %%
f.close()

# %% [markdown]
# ## CSVファイルに対するfor文
# CSVリーダもイテレータですので、for文の `in` の後に書くことができます。
#
# ---
# ```Python
# for row in dataReader:
#     ...
# ```
# ---
#
# 繰り返しの各ステップで、`next(dataReader)` が呼び出されて、
# `row` にその値が設定され、for文の中身が実行されます。

# %%
f = open('small.csv', 'r')
dataReader = csv.reader(f)
for row in dataReader:
    print(row)
f.close()
# Out:
# ['11', '12', '13', '14', '15']
# ['21', '22', '23', '24', '25']
# ['31', '32', '33', '34', '35']

# %% [markdown]
# ## CSVファイルに対するwith文
# 以下はwith文を使った例です。

# %%
with open('small.csv', 'r') as f:
    dataReader = csv.reader(f)
    for row in dataReader:
        print(row)
# Out:
# ['11', '12', '13', '14', '15']
# ['21', '22', '23', '24', '25']
# ['31', '32', '33', '34', '35']

# %% [markdown]
# ## CSVファイルの書き込み

# %% [markdown]
# CSVファイルを作成して書き込むには、CSVライターを作ります。
#
# **CSVライター**とは、CSVファイルを作ってデータを書き込むためのオブジェクトで、
# このオブジェクトのメソッドを呼び出すことにより、データがCSV形式でファイルに書き込まれます。
#
# CSVライターを作るには、
# **`csv`** というモジュールの **`csv.writer`** という関数にファイルオブジェクトを渡します。
# ここで、半角英数文字以外の文字（たとえば日本語文字や全角英数文字）を書き込み・書き出しする際には、
# 文字コード（たとえば `encoding='utf-8'`）を指定し、
# また書き出しの際にはさらに改行コードとして `newline=''` を指定しないと文字化けが生じる可能性があります。

# %%
f = open('out.csv', 'w', encoding='utf-8', newline='')

# %%
dataWriter = csv.writer(f)

# %%
dir(dataWriter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'dialect',
#  'writerow',
#  'writerows']

# %%
dataWriter.writerow([1,2,3])
# Out:
# 7

# %%
dataWriter.writerow([21,22,23])
# Out:
# 10

# %% [markdown]
# 書き込みモードの場合も、ファイルを使い終わったらクローズすることを忘れないようにしましょう。

# %%
f.close()

# %% [markdown]
# 読み込みのときと同様、with文を使うこともできます。

# %%
with open('out.csv', 'w', encoding='utf-8', newline='') as f:
    dataWriter = csv.writer(f)
    dataWriter.writerow([1,2,3])
    dataWriter.writerow([21,22,23])

# %% [markdown]
# ### 東京の7月の気温
# `tokyo-temps.csv` には、気象庁のオープンデータからダウンロードした、
# 東京の7月の平均気温のデータが入っています。
#
# http://www.data.jma.go.jp/gmd/risk/obsdl/
#
# 48行目の第2列に1875年7月の平均気温が入っており、
# 以下、2016年まで、12行ごとに7月の平均気温が入っています。

# %% [markdown]
# 以下は、これを取り出すPythonの簡単なコードです。

# %%
import csv
# import pandas as pd
# import numpy as np

with open('tokyo-temps.csv', 'r', encoding='shift_jis') as f:
    dataReader = csv.reader(f) # csvリーダを作成
    # test = pd.read_csv('tokyo-temps.csv', encoding='shift_jis')
    # test.head()
    n=0
    year = 1875
    years = []
    july_temps = []
    for row in dataReader: # CSVファイルの中身を1行ずつ読み込み
        n = n+1
        if n>=48 and (n-48)%12 == 0: # 48行目からはじめて12か月ごとにif内を実行
            years.append(year)
            july_temps.append(float(row[1]))
            year = year + 1

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2541137542.py in <cell line: 0>()
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %% [markdown]
# ファイルをオープンするときに、キーワード引数の **`encoding`** が指定されています。
# このファイルはShift_JISという文字コードで書かれているため、
# この引数で、ファイルの符号（**文字コード**）を指定します。
# `'shift_jis'` はShift_JISを意味します。この他に、`'utf-8'`（UTF-8、すなわちビットのUnicode）があります。

# %% [markdown]
# 変数 `years` に年の配列、変数 `july_temps` に対応する年の7月の平均気温の配列が設定されます。

# %%
years
# Out:
# [1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]

# %%
july_temps
# Out:
# [26.0,
#  24.3,
#  26.5,
#  26.0,
#  26.1,
#  24.2,
#  24.0,
#  24.2,
#  23.7,
#  23.4,
#  23.1,
#  25.0,
#  23.6,
#  24.5,
#  23.4,
#  23.5,
#  24.9,
#  25.7,
#  25.3,
#  26.8,
#  22.1,
#  24.1,
#  22.9,
#  25.9,
#  23.2,
#  22.8,
#  22.1,
#  21.8,
#  23.2,
#  24.8,
#  23.3,
#  23.5,
#  22.7,
#  22.1,
#  24.3,
#  23.0,
#  24.5,
#  24.3,
#  23.3,
#  25.5,
#  24.2,
#  23.9,
#  25.7,
#  26.0,
#  23.6,
#  26.1,
#  24.3,
#  25.0,
#  24.0,
#  26.1,
#  23.2,
#  24.6,
#  26.0,
#  23.4,
#  25.9,
#  26.3,
#  21.8,
#  25.7,
#  26.6,
#  23.9,
#  24.3,
#  24.9,
#  26.3,
#  25.0,
#  26.5,
#  26.9,
#  23.7,
#  27.5,
#  25.1,
#  25.6,
#  22.0,
#  26.2,
#  25.7,
#  26.0,
#  25.3,
#  26.5,
#  24.3,
#  24.3,
#  24.7,
#  22.3,
#  27.6,
#  24.2,
#  24.4,
#  24.9,
#  26.1,
#  25.8,
#  27.4,
#  25.1,
#  25.7,
#  25.5,
#  24.2,
#  24.4,
#  26.3,
#  24.7,
#  25.0,
#  25.4,
#  25.8,
#  25.2,
#  26.1,
#  23.4,
#  25.6,
#  23.9,
#  25.8,
#  27.8,
#  25.2,
#  23.8,
#  26.3,
#  23.1,
#  23.8,
#  26.2,
#  26.3,
#  23.9,
#  27.0,
#  22.4,
#  24.1,
#  25.7,
#  26.7,
#  25.5,
#  22.5,
#  28.3,
#  26.4,
#  26.2,
#  26.6,
#  25.3,
#  25.9,
#  27.7,
#  28.5,
#  28.0,
#  22.8,
#  28.5,
#  25.6,
#  25.6,
#  24.4,
#  27.0,
#  26.3,
#  28.0,
#  27.3,
#  26.4,
#  27.3,
#  26.8,
#  26.2,
#  25.4]

# %% [markdown]
# ここでは詳しく説明しませんが、**線形回帰**によるフィッティングを行ってみましょう。

# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

fitp = numpy.poly1d(numpy.polyfit(years, july_temps, 1))
ma = max(years)
mi = min(years)
xp = numpy.linspace(mi, ma, (ma - mi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1859797387.py in <cell line: 0>()
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4
# ----> 5 fitp = numpy.poly1d(numpy.polyfit(years, july_temps, 1))
#       6 ma = max(years)
#       7 mi = min(years)
#
# NameError: name 'years' is not defined

# %%
plt.plot(years, july_temps, '.', xp, fitp(xp), '-')
plt.show()

# %% [markdown]
# ## 練習
#
# 1. `tokyo-temps.csv` を読み込んで、各行が西暦年と7月の気温のみからなる `'tokyo-july-temps.csv'` という名前のCSVファイルを作成してください。
# 西暦年は1875から2016までとします。
#
# 2. 作成したCSVファイルをExcelで読み込むとどうなるか確認してください。

# %%
with open('tokyo-july-temps.csv', 'w', encoding='utf-8', newline='') as f:
    dataWriter = csv.writer(f)
    # i = 0
    for i in range(len(years)):
        dataWriter.writerow([years[i], july_temps[i]])

# %% [markdown]
# 以下のセルによってテストしてください。（`years` と `july_temps` の値がそのままと仮定しています。）

# %%
with open('tokyo-july-temps.csv', 'r', encoding='shift_jis') as f:
    i = 0
    dataReader = csv.reader(f)
    for row in dataReader:
        if int(row[0]) != years[i] or abs(float(row[1])-july_temps[i])>0.000001:
            print('error', int(row[0]), float(row[1]))
        i += 1
print(i== 142) # 1875年から2016年まで142年間分のデータがあるはずです
# Out:
# True

# %% [markdown]
# ## 練習
#
# 整数データのみからなるCSVファイルの名前を受け取ると、そのCSVファイルの各行を読み込んで整数のリストを作り、
# ファイル全体の内容を、そのようなリストのリストとして返す関数 `csv_matrix(name)` を定義してください。
#
# たとえば上で用いた `small.csv` には次のようなデータが入っています。
#
#
#  0列目 | 1列目 | 2列目 | 3列目 | 4列目
# ---|---|---|---|---
#  11 | 12 | 13 | 14 | 15
#  21 | 22 | 23 | 24 | 25
#  31 | 32 | 33 | 34 | 35
#
# この `small.csv` の名前が引数として与えられた場合、
#
# ```Python
# [[11, 12, 13, 14, 15], [21, 22, 23, 24, 25], [31, 32, 33, 34, 35]]
# ```
#
# というリストを返します。

# %%
def csv_matrix(name):
    list1 = []
    with open(name, 'r', encoding='utf-8') as f:
        dataReader = csv.reader(f)
        for row in dataReader:
            list2 = []
            for w in row:
                # print(w)
                list2.append(int(w))
                # print(list2)
            # print(row)
            list1.append(list2)
    # print(list1)
    return list1

# %% [markdown]
# 以下のセルによってテストしてください。

# %%
print(csv_matrix('small.csv') == [[11, 12, 13, 14, 15], [21, 22, 23, 24, 25], [31, 32, 33, 34, 35]])
# Out:
# True

# %% [markdown]
# ## 練習の解答

# %%
with open('tokyo-july-temps.csv', 'w', encoding='utf-8', newline='') as f:
    i = 0
    dataWriter = csv.writer(f)
    for i in range(len(years)):
        dataWriter.writerow([years[i],july_temps[i]])

# %%
def csv_matrix(name):
    rows = []
    with open(name, 'r') as f:
        dataReader = csv.reader(f)
        for row in dataReader:
            rows.append([int(x) for x in row])
    return rows
