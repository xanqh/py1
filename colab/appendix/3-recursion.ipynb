# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2025-11-28 10:48:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:52 (26.8 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2025-11-28 10:48:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.002s
#
# 2025-11-28 10:48:52 (13.9 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2025-11-28 10:48:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2025-11-28 10:48:53 (705 KB/s) - ‘./small.csv’ saved [45/45]
#
# --2025-11-28 10:48:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:53 (24.1 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2025-11-28 10:48:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2025-11-28 10:48:53 (366 KB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2025-11-28 10:48:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:48:53 (26.1 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2025-11-28 10:48:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2025-11-28 10:48:53 (578 KB/s) - ‘./sample.py’ saved [46/46]
#
# --2025-11-28 10:48:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:54 (67.1 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2025-11-28 10:48:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:54 (132 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2025-11-28 10:48:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.008s
#
# 2025-11-28 10:48:54 (8.20 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2025-11-28 10:48:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:48:54 (24.4 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2025-11-28 10:48:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:55 (83.4 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2025-11-28 10:48:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0.002s
#
# 2025-11-28 10:48:55 (12.4 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2025-11-28 10:48:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.002s
#
# 2025-11-28 10:48:55 (15.3 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2025-11-28 10:48:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:55 (93.1 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2025-11-28 10:48:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:48:55 (13.8 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2025-11-28 10:48:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.009s
#
# 2025-11-28 10:48:56 (5.92 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2025-11-28 10:48:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:56 (71.6 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2025-11-28 10:48:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.02s
#
# 2025-11-28 10:48:56 (13.7 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2025-11-28 10:48:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.009s
#
# 2025-11-28 10:48:56 (6.13 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2025-11-28 10:48:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:48:56 (22.3 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2025-11-28 10:48:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0s
#
# 2025-11-28 10:48:57 (59.0 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2025-11-28 10:48:57--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.007s
#
# 2025-11-28 10:48:57 (8.49 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2025-11-28 10:48:57--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:48:57 (18.9 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2025-11-28 10:48:57--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.007s
#
# 2025-11-28 10:48:57 (8.50 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲再帰
# **再帰**について説明します。
#
# 関数の**再帰呼び出し**とは、定義しようとしている関数を、その定義の中で呼び出すことです。
# 定義の中で直接呼び出す場合に限らず、他の関数を経由して間接的に呼び出す場合も、再帰呼び出しに含まれます。
# 再帰呼び出しを行う関数を、**再帰関数**といいます。
#
# 再帰関数は、**分割統治**アルゴリズムの記述に適しています。
# 分割統治とは、問題を容易に解ける小さな粒度まで分割していき、
# 個々の小さな問題を解いて、その部分解を合成することで問題全体を解くような方法を指します。
# 分割統治の考え方は、関数型プログラミングにおいてもよく用いられます。
# 再帰関数による分割統治の典型的な形は、次の通りです。
#
# ```Python
# def recursive_function(...):
#     if 問題粒度の判定:
#         再帰呼び出しを含まない基本処理
#     else:
#         再帰呼び出しを含む処理（問題の分割や部分解の合成を行う）
# ```

# %% [markdown]
# 以下で、再帰関数を使った処理の例をいくつか見ていきましょう。

# %% [markdown]
# ## 再帰関数の例：接頭辞リストと接尾辞リスト

# %%
# 入力の文字列の接頭辞リストを返す関数prefixes
def prefixes(s):
    if s == '':
        return []
    else:
        return [s] + prefixes(s[:-1])

prefixes('aabcc')
# Out:
# ['aabcc', 'aabc', 'aab', 'aa', 'a']

# %%
# 入力の文字列の接尾辞リストを返す関数suffixes
def suffixes(s):
    if s == '':
        return []
    else:
        return [s] + suffixes(s[1:])

suffixes('aabcc')
# Out:
# ['aabcc', 'abcc', 'bcc', 'cc', 'c']

# %% [markdown]
# ## 再帰関数の例：べき乗の計算

# %%
# 入力の底baseと冪指数exptからべき乗を計算する関数power
def power(base, expt):
    if expt == 0:
        # exptが0ならば1を返す
        return 1
    else:
        # exptを1つずつ減らしながらpowerに渡し、再帰的にべき乗を計算
        # (2*(2*(2*....*1)))
        return base * power(base, expt - 1)

power(2,10)
# Out:
# 1024

# %% [markdown]
# 一般に、再帰処理は、繰り返し処理としても書くことができます。

# %%
# べき乗の計算を繰り返し処理で行った例
def power(base, expt):
    e = 1
    for i in range(expt):
        e *= base
    return e

power(2,10)
# Out:
# 1024

# %% [markdown]
# 単純な処理においては、繰り返しの方が効率的に計算できることが多いですが、
# 特に複雑な処理になってくると、再帰的に定義した方が読みやすいコードで効率的なアルゴリズムを記述できることもあります。
# たとえば、次に示すべき乗計算は、上記よりも高速なアルゴリズムですが、計算の見通しは明快です。

# %%
# べき乗を計算する高速なアルゴリズム
def power(base, expt):
    if expt == 0:
        return 1
    elif expt % 2 == 0:
        return power(base * base, expt // 2) # x**(2m) == (x*x)**m
    else:
        return base * power(base, expt - 1)

power(2,10)
# Out:
# 1024

# %% [markdown]
# ## 再帰関数の例：マージソート
#
# マージソートは、典型的な分割統治アルゴリズムで、以下のように再帰関数で実装することができます。

# %%
# マージソートを行い、比較回数 n を返す
def merge_sort_rec(data, l, r, work):
    n = 0
    if r - l <= 1:
        return n
    m = l + (r - l) // 2
    n1 = merge_sort_rec(data, l, m, work)
    n2 = merge_sort_rec(data, m, r, work)
    i1 = l
    i2 = m
    for i in range(l, r):
        from1 = False
        if i2 >= r:
            from1 = True
        elif i1 < m:
            n = n + 1
            if data[i1] <= data[i2]:
                from1 = True
        if from1:
            work[i] = data[i1]
            i1 = i1 + 1
        else:
            work[i] = data[i2]
            i2 = i2 + 1
    for i in range(l, r):
        data[i] = work[i]
    return n1 + n2 + n

def merge_sort(data):
    return merge_sort_rec(data, 0, len(data), [0]*len(data))

# %%
def merge_sort_rec(data, l, r, work):
    n = 0
    if r - l <= 1:
        return n
    m = l + (r - l) // 2
    n1 = merge_sort_rec(data, l, m, work)
    n2 = merge_sort_rec(data, m, r, work)
    i1 = l
    i2 = m
    for i in range(l, r):
        from1 = False
        if i2 >= r:
            from1 = True
        elif i1 < m:
            n = n + 1
            if data[i1] <= data[i2]:
                from1 = True
        if from1:
            work[i] = data[i1]
            i1 = i1 + 1
        else:
            work[i] = data[i2]
            i2 = i2 + 1
    for i in range(l, r):
        data[i] = work[i]
    return n1 + n2 + n

def merge_sort(data):
    return merge_sort_rec(data, 0, len(data), [0]*len(data))

# %% [markdown]
# `merge_sort` は、与えられた配列をインプレースでソートするとともに、比較の回数を返します。
# `merge_sort` は、再帰関数 `merge_sort_rec` を呼び出します。
#
# `merge_sort_rec(data, l, r, work)` は、配列 `data` のインデックスが `l` 以上で `r` より小さいところをソートします。
#
# - 要素が1つかないときは何もしません。
# - そうでなければ、`l` から　`r` までの要素を半分にしてそれぞれを再帰的にソートします。
# - その結果を作業用の配列 `work` に順序を保ちながらコピーします。この操作はマージ（併合）と呼ばれます。
# - 最後に、`work` から `data` に要素を戻します。
#
# `merge_sort_rec` は自分自身を2回呼び出していますので、繰り返しでは容易には実装できません。

# %%
import random
a = [random.randint(1,10000) for i in range(100)]
merge_sort(a)
# Out:
# 540

# %%
a
# Out:
# [91,
#  98,
#  269,
#  299,
#  379,
#  544,
#  595,
#  664,
#  666,
#  694,
#  916,
#  939,
#  994,
#  1205,
#  1207,
#  1384,
#  1456,
#  1489,
#  1591,
#  1620,
#  1630,
#  1690,
#  1748,
#  1752,
#  1864,
#  2113,
#  2233,
#  2241,
#  2391,
#  2431,
#  2443,
#  2603,
#  2768,
#  2869,
#  2906,
#  3330,
#  3369,
#  3469,
#  3585,
#  3735,
#  3970,
#  3989,
#  4053,
#  4106,
#  4326,
#  4326,
#  4328,
#  4346,
#  4356,
#  4914,
#  4999,
#  5013,
#  5065,
#  5190,
#  5284,
#  5357,
#  5575,
#  5617,
#  5643,
#  5765,
#  5767,
#  5794,
#  5880,
#  6134,
#  6276,
#  6299,
#  6483,
#  6686,
#  6901,
#  6931,
#  6984,
#  6988,
#  7028,
#  7120,
#  7302,
#  7316,
#  7617,
#  7739,
#  7768,
#  7887,
#  8076,
#  8165,
#  8209,
#  8358,
#  8359,
#  8521,
#  8673,
#  8710,
#  8738,
#  8763,
#  8993,
#  9032,
#  9090,
#  9100,
#  9259,
#  9303,
#  9494,
#  9713,
#  9716,
#  9722]
