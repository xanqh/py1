# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2025-11-28 10:24:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2025-11-28 10:24:37 (24.9 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2025-11-28 10:24:37--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.009s
#
# 2025-11-28 10:24:37 (2.98 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2025-11-28 10:24:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2025-11-28 10:24:38 (2.30 MB/s) - ‘./small.csv’ saved [45/45]
#
# --2025-11-28 10:24:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2025-11-28 10:24:38 (26.5 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2025-11-28 10:24:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2025-11-28 10:24:38 (1.86 MB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2025-11-28 10:24:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.01s
#
# 2025-11-28 10:24:38 (3.07 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2025-11-28 10:24:38--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2025-11-28 10:24:39 (691 KB/s) - ‘./sample.py’ saved [46/46]
#
# --2025-11-28 10:24:39--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:24:39 (8.97 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2025-11-28 10:24:39--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0.01s
#
# 2025-11-28 10:24:39 (2.93 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2025-11-28 10:24:39--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.04s
#
# 2025-11-28 10:24:39 (1.72 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2025-11-28 10:24:40--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0.006s
#
# 2025-11-28 10:24:40 (3.77 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2025-11-28 10:24:40--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:24:40 (11.7 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2025-11-28 10:24:40--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0.006s
#
# 2025-11-28 10:24:40 (3.39 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2025-11-28 10:24:40--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.01s
#
# 2025-11-28 10:24:40 (2.96 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2025-11-28 10:24:40--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2025-11-28 10:24:40 (72.5 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2025-11-28 10:24:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.006s
#
# 2025-11-28 10:24:41 (3.35 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2025-11-28 10:24:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.04s
#
# 2025-11-28 10:24:41 (1.41 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2025-11-28 10:24:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0.001s
#
# 2025-11-28 10:24:41 (11.7 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2025-11-28 10:24:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.09s
#
# 2025-11-28 10:24:41 (2.60 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2025-11-28 10:24:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.04s
#
# 2025-11-28 10:24:42 (1.25 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2025-11-28 10:24:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.004s
#
# 2025-11-28 10:24:42 (3.74 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2025-11-28 10:24:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0.002s
#
# 2025-11-28 10:24:42 (5.38 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2025-11-28 10:24:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.04s
#
# 2025-11-28 10:24:42 (1.46 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2025-11-28 10:24:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.008s
#
# 2025-11-28 10:24:43 (3.50 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2025-11-28 10:24:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.04s
#
# 2025-11-28 10:24:43 (1.30 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲セット (set)
# セットについて説明します。
#
# 参考
#
# - https://docs.python.org/ja/3/tutorial/datastructures.html#sets
#
# **セット**（**集合**）は、リストと同様に複数の要素から構成されるデータです。
# セットでは、リストと異なり要素の重複がありません、また要素の順番もありません。
#
# セットを作成するには、次のように波括弧で要素を囲みます。
# 辞書と似ていますが、辞書では `:` でキーと値を対応させる必要がありました。

# %%
set1= {2, 1, 2, 3, 2, 3, 1, 3, 3, 1}
set1
# Out:
# {1, 2, 3}

# %%
type(set1)
# Out:
# set

# %% [markdown]
# セットのデータ型は **`set`** であり、`set` は組み込み関数でもあります。
#
# 組み込み関数 `set` を用いてもセットを作成することができます。

# %%
set([2, 1, 2, 3, 2, 3, 1, 3, 3, 1])
# Out:
# {1, 2, 3}

# %% [markdown]
# 空のセットを作成する場合、次のようにします。（ `{}` では空の辞書が作成されます。）

# %%
set2 = set() # 空のセット
set2
# Out:
# set()

# %%
set2 = {} # 空の辞書
set2
# Out:
# {}

# %% [markdown]
# `set` を用いて、文字列、リストやタプルなどからセットを作成することができます。

# %%
set([1,1,2,2,2,3])
# Out:
# {1, 2, 3}

# %%
set((1,1,2,2,2,3))
# Out:
# {1, 2, 3}

# %%
set('aabdceabdae')
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
set({'apple' : 3, 'pen' : 5})
# Out:
# {'apple', 'pen'}

# %% [markdown]
# ## セットの組み込み関数
# リストなどと同様に、次の関数などはセットにも適用可能です。

# %%
len(set1) # 集合を構成する要素数
# Out:
# 3

# %%
x,y,z = set1 # 多重代入
x
# Out:
# 1

# %%
2 in set1 # 指定した要素を集合が含むかどうかの判定
# Out:
# True

# %%
10 in set1 # 指定した要素を集合が含むかどうかの判定
# Out:
# False

# %%
10 not in set1
# Out:
# True

# %% [markdown]
# セットの要素は、順序付けられていないのでインデックスを指定して取り出すことはできません。

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2166654704.py in <cell line: 0>()
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## 練習
#
# 文字列 `str1` が引数として与えられたとき、`str1` に含まれる要素（文字、すなわち長さ1の文字列）の種類を返す関数 `check_characters` を作成してください（大文字と小文字は区別し、スペースや句読点も1つと数えます）。
# たとえば、`'aabccc'` には `'a'` と `'b'` と `'c'` が含まれるので、
# `check_characters('aabccc')` は 3 を返します。
#
# 以下のセルの `...` のところを書き換えて `check_characters(str1)` を作成してください。

# %%
def check_characters(str1):
    return len(set(str1))

# %% [markdown]
# 上のセルで解答を作成した後、以下のセルを実行し、実行結果が `True` になることを確認してください。

# %%
print(check_characters('Onde a terra acaba e o mar começa') == 13)
# Out:
# True

# %% [markdown]
# ## 練習
#
# 辞書 `dic1` が引数として与えられたとき、`dic1` に登録されているキーの数を返す関数 `check_dicsize` を作成してください。
#
# 以下のセルの `...` のところを書き換えて `check_dicsize(dic1)` を作成してください。

# %%
def check_dicsize(dic1):
    return len(set(dic1))

# %% [markdown]
# 上のセルで解答を作成した後、以下のセルを実行し、実行結果が `True` になることを確認してください。

# %%
print(check_dicsize({'apple': 0, 'orange': 2, 'pen': 1}) == 3)
# Out:
# True

# %% [markdown]
# ## **集合演算**
# 複数のセットから、**和集合**・**積集合**・**差集合**・**対称差**を求める集合演算が存在します。

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1 | set2 # 和集合
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1 & set2 # 積集合
# Out:
# {3, 4}

# %%
set1 - set2 # 差集合
# Out:
# {1, 2}

# %%
set1 ^ set2 # 対称差
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# ## **比較演算**
# 数値などを比較するのに用いた比較演算子を用いて、2つのセットを比較することもできます。

# %%
print({1, 2, 3} == {1, 2, 3, 3})
print({1, 2} == {1, 2, 3})
# Out:
# True
# False

# %%
print({1, 2, 3} != {1, 2, 3})
print({1, 2} != {1, 2, 3})
# Out:
# False
# True

# %% [markdown]
# `<=` や `<` は、集合の間の包含関係を判定します。

# %%
print({1, 2, 3} <= {1, 2, 3})
print({1, 2, 3} < {1, 2, 3})
print({1, 2} < {1, 2, 3})
# Out:
# True
# False
# True

# %%
print({1, 2} <= {2, 3, 4})
# Out:
# False

# %% [markdown]
# ## セットのメソッド
# セットにも様々なメソッドが存在します。なお、以下のメソッドは全て破壊的です。

# %% [markdown]
# ### **add**
# 指定した要素を新たにセットに追加します。

# %%
set1 = {1, 2, 3}
set1.add(4)
set1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# ### **remove**
# 指定した要素をセットから削除します。
# その要素がセットに含まれていない場合、エラーになります。

# %%
set1.remove(1)
set1
# Out:
# {2, 3, 4}

# %%
set1.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-760318040.py in <cell line: 0>()
# ----> 1 set1.remove(10)
#
# KeyError: 10

# %% [markdown]
# ### **discard**
# 指定した要素をセットから削除します。
# その要素がセットに含まれていなくともエラーになりません。

# %%
set1 = {1, 2, 3, 4}
set1.discard(1)
set1
# Out:
# {2, 3, 4}

# %%
set1.discard(5)
set1
# Out:
# {2, 3, 4}

# %% [markdown]
# ### **clear**
# 全ての要素を削除して対象のセットを空にします。

# %%
set1 = {1, 2, 3, 4}
set1.clear()
set1
# Out:
# set()

# %% [markdown]
# ### **pop**
# セットからランダムに1つの要素を取り出します。

# %%
set1 = {1, 2, 3, 4}
print(set1.pop())
print(set1)
# Out:
# 1
# {2, 3, 4}

# %% [markdown]
# ### **union**, **intersection**, **difference**
# **和集合**・**積集合**・**差集合**・**対称差**を求めるメソッドも存在します。

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
set1.union(set2) # 和集合
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2) # 積集合
# Out:
# {3, 4}

# %%
set1.difference(set2) # 差集合
# Out:
# {1, 2}

# %%
set1.symmetric_difference(set2) # 対称差
# Out:
# {1, 2, 5, 6}

# %% [markdown]
# ## 練習
#
# 英語の文章からなる文字列 `str_engsentences` が引数として与えられたとき、`str_engsentences` 中に含まれる単語の種類数を返す関数 `count_words2` を作成してください。
#
# 以下のセルの `...` のところを書き換えて `count_words2(str_engsentences)` を作成してください。

# %%
def count_words2(str_engsentences):
    str_engsentences = str_engsentences.replace(',', '')
    str_engsentences = str_engsentences.replace('.', '')
    str_engsentences = str_engsentences.replace('!', '')
    str_engsentences = str_engsentences.replace('?', '')
    list1 = str_engsentences.split(' ')
    print(len(list1))
    return len(set(list1))

# %% [markdown]
# 上のセルで解答を作成した後、以下のセルを実行し、実行結果が `True` になることを確認してください。

# %%
print(count_words2('From Stettin in the Baltic to Trieste in the Adriatic an iron curtain has descended across the Continent.') == 15)
# Out:
# 18
# True

# %%
print(set('aabbcc'))
print(set(['a', 'a', 'b', 'b', 'c', 'c']))

print(set('abracadabra'))
print(set(['apple', 'banana', 'apple', 'orange']))
# Out:
# {'b', 'c', 'a'}
# {'b', 'c', 'a'}
# {'c', 'a', 'd', 'b', 'r'}
# {'apple', 'orange', 'banana'}

# %% [markdown]
# ## 練習の解答

# %%
def check_characters(str1):
    set1 = set(str1)
    return len(set1)
#check_characters('Onde a terra acaba e o mar começa')

# %%
def check_dicsize(dic1):
    return len(set(dic1))
#check_dicsize({'apple': 0, 'orange': 2, 'pen': 1})

# %% [markdown]
# 実は `len` は辞書に対してキーの数を返すので、セットを使う必要はありません。

# %%
def check_dicsize(dic1):
    return len(dic1)

# %%
def count_words2(str_engsentences):
    str1 = str_engsentences.replace('.', '') # 句読点を削除する
    str1 = str1.replace(',', '')
    str1 = str1.replace(':', '')
    str1 = str1.replace(';', '')
    str1 = str1.replace('!', '')
    str1 = str1.replace('?', '')
    list1 = str1.split(' ') # 句読点を削除した文字列を、単語ごとにリストに格納する
    set1 = set(list1) # リストを集合に変換して同じ要素を1つにまとめる
    return len(set1)
#count_words2('From Stettin in the Baltic to Trieste in the Adriatic an iron curtain has descended across the Continent.')
