# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2025-11-28 12:02:49--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:50 (28.0 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2025-11-28 12:02:50--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.001s
#
# 2025-11-28 12:02:50 (20.2 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2025-11-28 12:02:50--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2025-11-28 12:02:50 (667 KB/s) - ‘./small.csv’ saved [45/45]
#
# --2025-11-28 12:02:50--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:50 (25.5 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2025-11-28 12:02:50--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2025-11-28 12:02:51 (488 KB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2025-11-28 12:02:51--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.003s
#
# 2025-11-28 12:02:51 (9.50 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2025-11-28 12:02:51--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2025-11-28 12:02:51 (2.04 MB/s) - ‘./sample.py’ saved [46/46]
#
# --2025-11-28 12:02:51--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:51 (67.7 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2025-11-28 12:02:51--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0.01s
#
# 2025-11-28 12:02:52 (2.83 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2025-11-28 12:02:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.007s
#
# 2025-11-28 12:02:52 (10.1 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2025-11-28 12:02:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:52 (89.9 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2025-11-28 12:02:52--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:53 (76.7 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2025-11-28 12:02:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:53 (101 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2025-11-28 12:02:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.005s
#
# 2025-11-28 12:02:53 (7.09 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2025-11-28 12:02:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:53 (70.7 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2025-11-28 12:02:53--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.001s
#
# 2025-11-28 12:02:54 (13.7 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2025-11-28 12:02:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.008s
#
# 2025-11-28 12:02:54 (6.85 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2025-11-28 12:02:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0.001s
#
# 2025-11-28 12:02:54 (18.7 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2025-11-28 12:02:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.01s
#
# 2025-11-28 12:02:54 (16.2 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2025-11-28 12:02:54--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.007s
#
# 2025-11-28 12:02:55 (7.75 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2025-11-28 12:02:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.001s
#
# 2025-11-28 12:02:55 (32.4 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2025-11-28 12:02:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0s
#
# 2025-11-28 12:02:55 (61.6 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2025-11-28 12:02:55--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.008s
#
# 2025-11-28 12:02:55 (7.27 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2025-11-28 12:02:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.002s
#
# 2025-11-28 12:02:56 (11.6 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2025-11-28 12:02:56--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.006s
#
# 2025-11-28 12:02:56 (8.98 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲簡単なデータの可視化
# 第3回までに学んだ各種のデータに対する簡単な可視化について触れます。
#
# 参考
#
# - https://matplotlib.org/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py (English Only)
#
# `matplotlib` については、5-matplotlib に詳しい説明があります。

# %% [markdown]
# ## **`matplotlib`**
#
# Pythonでは可視化のための様々な仕組みが用意されています。
# ここでは最も広く利用され、ノートブック上で容易に動作を確認できる `matplotlib` について触れます。
# `matplotlib` を利用するには第5回で取り上げるモジュールについても知る必要がありますが、
# 第2回と第3回でデータについてだけ学ぶのでは、みなさんのモチベーションの維持が難しいと思われますので、
# この段階でリスト・辞書だけで2次元グラフを表示させてみます。
# したがって、ここではモジュールの使い方については説明しません。

# %% [markdown]
# `matplotlib` の出力をノートブックで表示させるには、以下をCodeセルで1回だけ実行します。
# `%matplotlib` のように `%` で始まる文を**マジックコマンド**と呼びます。

# %%
# %matplotlib inline

# %% [markdown]
# さらに `matplotlib` モジュールを読み込む次の処理もプログラムの冒頭で行う必要があります。
#
# ```Python
# import matplotlib.pyplot as plt
# ```

# %% [markdown]
# ## 折れ線グラフ
#
# `ls1 = [1, 4, 9, 16]` といった数を要素とするリストを折れ線グラフで表示するには、次のように行います。

# %%
import matplotlib.pyplot as plt
ls1 = [1, 4, 9, 16]
plt.plot(ls1)
plt.show()

# %% [markdown]
# 折れ線グラフを複数表示させるには、`plt.plot` を繰り返します。

# %%
import matplotlib.pyplot as plt
ls1 = [1, 4, 9, 16]
ls2 = [8, 7, 6, 5]
plt.plot(ls1, label='1st plot')
plt.plot(ls2, label='2nd plot')
plt.show()

# %% [markdown]
# ## 散布図
# 散布図を表示させるには、`plt.scatter` にそれぞれの点に対応する水平、垂直座標をリストで与えます。
# この2つのリストの要素数は同じでなければなりません。

# %%
import matplotlib.pyplot as plt
x = [5, 10, 15, 10, 20]
y = [10, 5, 10, 15, 20]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## 棒グラフ
# 棒グラフを表示させるには、`plt.bar` に水平座標、高さをリストで与えます。
# この2つのリストの要素数は同じでなければなりません。
# 以下の例では、等間隔でグラフを表示させるため水平軸に整数列を使っています。

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 30, 40, 15]
plt.bar(x,y)
plt.show()

# %% [markdown]
# 第2回と第3回では文字列、辞書について学びました。
# 文字列をキー、整数を値とする辞書を棒グラフで可視化します。
# さらに、水平軸にはキーをラベルとして表示されます。

# %%
import matplotlib.pyplot as plt
d = {'apple':10, 'banana':30, 'orange': 40, 'kiwi': 15}
x = [1,2,3,4]
plt.bar(x, d.values(), tick_label=list(d.keys()))
plt.show()
